# %% [markdown]
# pip freeze - to see the versions of the library

# %% [markdown]
# pip instal (pakage name) - to install a pakage in git

# %% [markdown]
# pip uninstal (pakage name) - to uninstall a pakage in git
